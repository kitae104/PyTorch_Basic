# %% [markdown]
# ### 1. 모듈 임포트

# %%
import numpy as np # 수치 계산 라이브러리
import matplotlib.pyplot as plt # 시각화 라이브러리
import torch # PyTorch 라이브러리
import torch.nn as nn # 딥러닝 모델을 구성하는데 필요한 모듈
import torch.nn.functional as F # 활성화 함수 등 다양한 함수 제공
from torchvision import transforms, datasets # 이미지 데이터셋과 변환 도구 제공

# %% [markdown]
# ### 2. 딥러닝 모델을 설계할 때 활용하는 장비 확인

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

print('파이토치 버전 :', torch.__version__, '사용 디바이스 :', device)

BATCH_SIZE = 32 # 배치 크기
EPOCHS = 10 # 학습 반복 횟수
# Out:
# 파이토치 버전 : 2.6.0+cu124 사용 디바이스 : cuda

# %% [markdown]
# ### 3. MNIST 데이터 다운로드 (Train set, Test set 분리하기)

# %%
train_dataset = datasets.MNIST(
    root= "../data/MNIST",  # 데이터셋 저장 경로
    train= True, # 학습용 데이터 설정
    download= True, # 데이터셋이 없으면 다운로드
    transform = transforms.ToTensor() # 데이터를 텐서로 변환
)

test_dataset = datasets.MNIST(
    root= "../data/MNIST",  # 데이터셋 저장 경로
    train= False, # 테스트용 데이터 설정
    transform= transforms.ToTensor() # 데이터를 텐서로 변환
)

train_loader = torch.utils.data.DataLoader(
    dataset = train_dataset,
    batch_size = BATCH_SIZE,
    shuffle = True # 매 epoch마다 데이터 섞기
)

test_loader = torch.utils.data.DataLoader(
    dataset = test_dataset,
    batch_size = BATCH_SIZE,
    shuffle = False # 테스트 데이터는 섞지 않음
)

# %% [markdown]
# ### 4. 데이터 확인하기 (1)

# %%
for (X_train, y_train) in train_loader:
    print('X_train 크기:', X_train.size(), 'X_train 타입:', X_train.type())
    print('y_train 크기:', y_train.size(), 'y_train 타입:', y_train.type())
    break   # 첫 번째 배치만 확인
# Out:
# X_train 크기: torch.Size([32, 1, 28, 28]) X_train 타입: torch.FloatTensor
# y_train 크기: torch.Size([32]) y_train 타입: torch.LongTensor

# %% [markdown]
# ### 5. 데이터 확인하기 (2)

# %%
pltsize = 1 
plt.figure(figsize=(10 * pltsize, pltsize)) # 그래프 크기 설정

for i in range(10):
    plt.subplot(1, 10, i +1) # 1행 10열 서브플롯
    plt.axis('off') # 축 숨기기
    plt.imshow(X_train[i, :, :, :].numpy().reshape(28, 28), cmap="gray_r") # 이미지 출력
    plt.title('Class: ' + str(y_train[i].item())) # 타이틀

# %% [markdown]
# ### 6. Multi Layer Perceptron (MLP) 모델 설계하기
# - relu() 적용

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(28 * 28, 512) # 첫 번째 완전 연결층
        self.fc2 = nn.Linear(512, 256)     # 두 번째 완전 연결층
        self.fc3 = nn.Linear(256, 10)      # 세 번째 완전 연결층

        ####### dropout 추가 #######
        self.dropout_prob = 0.5          # 드롭아웃 확률 설정

        ####### batch normalization 추가 #######
        self.batch_norm1 = nn.BatchNorm1d(512)  # 첫 번째 배치 정규화 층
        self.batch_norm2 = nn.BatchNorm1d(256)  # 두 번째 배치 정규화 층

    def forward(self, x):
        x = x.view(-1, 28 * 28)            # 입력 이미지 평탄화
        x = self.fc1(x)                    # 첫 번째 층

        x = self.batch_norm1(x)            # 배치 정규화 적용
        
        x = F.relu(x)                  # ReLU 활성화 함수

        x = F.dropout(x, training=self.training, p=self.dropout_prob)  # 드롭아웃 적용
        
        x = self.fc2(x)                    # 두 번째 층

        x = self.batch_norm2(x)            # 배치 정규화 적용
        
        x = F.relu(x)                  # ReLU 활성화 함수

        x = F.dropout(x, training=self.training, p=self.dropout_prob)  # 드롭아웃 적용

        x = self.fc3(x)                    # 세 번째 층 (출력층)
        x = F.log_softmax(x, dim=1)       # 소프트맥스 활성화 함수
        return x

# %% [markdown]
# ### 7. Optimizer, Objective Function 설정하기

# %%
import torch.nn.init as init

def weight_init(m):
    if isinstance(m, nn.Linear):
        init.kaiming_uniform_(m.weight) # He 초기화
        #init.constant_(m.bias, 0)       # 편향을 0으로 초기화


model = Net().to(device) # 모델을 디바이스(GPU/CPU)로 이동

model.apply(weight_init) # 가중치 초기화 함수 적용

optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.5) # 옵티마이저 설정
criterion = nn.CrossEntropyLoss() # 손실 함수 설정

print(model)
# Out:
# Net(
#   (fc1): Linear(in_features=784, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=10, bias=True)
#   (batch_norm1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batch_norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %% [markdown]
# ### 8. MLP 모델 학습을 진행하며 학습 데이터에 대한 모델 성능을 확인하는 함수 정의

# %%
def train(model, train_loader, optimizer, log_interval):
    model.train() # 모델을 학습 모드로 설정
    
    for batch_idx, (image, label) in enumerate(train_loader):
        image = image.to(device) # 이미지 데이터를 디바이스로 이동
        label = label.to(device) # 레이블 데이터를 디바이스로 이동
        optimizer.zero_grad() # 기울기 초기화
        output = model(image) # 모델에 이미지 입력하여 출력 계산
        losss = criterion(output, label) # 손실 계산
        losss.backward() # 역전파로 기울기 계산
        optimizer.step() # 가중치 업데이트

        if batch_idx % log_interval == 0:   # 일정 간격마다 로그 출력
            print('학습 Epoch: {} [{}/{} ({:.0f}%)]\t학습 손실(Loss) : {:.6f}'.format(
                epoch, batch_idx * len(image), # 현재까지 학습한 데이터 수
                len(train_loader.dataset), # 전체 학습 데이터 수
                100. * batch_idx / len(train_loader), # 학습 진행률
                losss.item() # 현재 배치의 손실 값
            ))

# %% [markdown]
# ### 9. 학습되는 과정 속에서 검증 데이터에 대한 모델 성능을 확인하는 함수 정의

# %%
def evaluate(model, test_loader):
    model.eval() # 모델을 평가 모드로 설정
    test_loss = 0   # 테스트 손실 초기화
    correct = 0  # 맞춘 개수 초기화

    with torch.no_grad(): # 평가 시에는 기울기 계산하지 않음
        for image, label in test_loader:
            image = image.to(device) # 이미지 데이터를 디바이스로 이동
            label = label.to(device) # 레이블 데이터를 디바이스로 이동
            output = model(image) # 모델에 이미지 입력하여 출력 계산
            test_loss += criterion(output, label).item() # 배치 손실 누적
            prediction = output.argmax(dim=1, keepdim=True) # 가장 높은 확률의 클래스 선택
            correct += prediction.eq(label.view_as(prediction)).sum().item() # 정답과 비교하여 맞춘 개수 누적

    test_loss /= len(test_loader.dataset) # 평균 손실 계산
    test_accuracy = 100. * correct / len(test_loader.dataset) # 정확도 계산    

    return test_loss, test_accuracy # 평가 손실과 정확도 반환

# %% [markdown]
# ### 10. MLP 학습 실행하며 Train, Test set의 Loss 및 Test set Accuracy 확인하기

# %%
for epoch in range(1, EPOCHS + 1):
    train(model, train_loader, optimizer, log_interval=200) # 모델 학습
    test_loss, test_accuracy = evaluate(model, test_loader) # 모델 평가
    print("\n-------------------------------------------------------------------------------------")
    print(f"Epoch {epoch}:      Test Loss: {test_loss:.4f},     Test Accuracy: {test_accuracy:.2f}%")
    print("-------------------------------------------------------------------------------------\n")
# Out:
# 학습 Epoch: 1 [0/60000 (0%)]	학습 손실(Loss) : 3.000474
# 학습 Epoch: 1 [6400/60000 (11%)]	학습 손실(Loss) : 0.955930
# 학습 Epoch: 1 [12800/60000 (21%)]	학습 손실(Loss) : 0.637126
# 학습 Epoch: 1 [19200/60000 (32%)]	학습 손실(Loss) : 0.414867
# 학습 Epoch: 1 [25600/60000 (43%)]	학습 손실(Loss) : 0.552488
# 학습 Epoch: 1 [32000/60000 (53%)]	학습 손실(Loss) : 0.283918
# 학습 Epoch: 1 [38400/60000 (64%)]	학습 손실(Loss) : 0.518000
# 학습 Epoch: 1 [44800/60000 (75%)]	학습 손실(Loss) : 0.334373
# 학습 Epoch: 1 [51200/60000 (85%)]	학습 손실(Loss) : 0.289220
# 학습 Epoch: 1 [57600/60000 (96%)]	학습 손실(Loss) : 0.481511
#
# -------------------------------------------------------------------------------------
# Epoch 1:      Test Loss: 0.0069,     Test Accuracy: 93.43%
# -------------------------------------------------------------------------------------
#
# 학습 Epoch: 2 [0/60000 (0%)]	학습 손실(Loss) : 0.513120
# 학습 Epoch: 2 [6400/60000 (11%)]	학습 손실(Loss) : 0.511289
# 학습 Epoch: 2 [12800/60000 (21%)]	학습 손실(Loss) : 0.309053
# 학습 Epoch: 2 [19200/60000 (32%)]	학습 손실(Loss) : 0.390104
# 학습 Epoch: 2 [25600/60000 (43%)]	학습 손실(Loss) : 0.373850
# 학습 Epoch: 2 [32000/60000 (53%)]	학습 손실(Loss) : 0.103901
# 학습 Epoch: 2 [38400/60000 (64%)]	학습 손실(Loss) : 0.420133
# 학습 Epoch: 2 [44800/60000 (75%)]	학습 손실(Loss) : 0.398741
# 학습 Epoch: 2 [51200/60000 (85%)]	학습 손실(Loss) : 0.245829
# 학습 Epoch: 2 [57600/60000 (96%)]	학습 손실(Loss) : 0.219268
#
# -------------------------------------------------------------------------------------
# Epoch 2:      Test Loss: 0.0054,     Test Accuracy: 94.88%
# -------------------------------------------------------------------------------------
#
# 학습 Epoch: 3 [0/60000 (0%)]	학습 손실(Loss) : 0.411241
# 학습 Epoch: 3 [6400/60000 (11%)]	학습 손실(Loss) : 0.108595
# 학습 Epoch: 3 [12800/60000 (21%)]	학습 손실(Loss) : 0.528584
# 학습 Epoch: 3 [19200/60000 (32%)]	학습 손실(Loss) : 0.269250
# 학습 Epoch: 3 [25600/60000 (43%)]	학습 손실(Loss) : 0.462919
# 학습 Epoch: 3 [32000/60000 (53%)]	학습 손실(Loss) : 0.965882
# 학습 Epoch: 3 [38400/60000 (64%)]	학습 손실(Loss) : 0.198848
# 학습 Epoch: 3 [44800/60000 (75%)]	학습 손실(Loss) : 0.183834
# 학습 Epoch: 3 [51200/60000 (85%)]	학습 손실(Loss) : 0.217035
# 학습 Epoch: 3 [57600/60000 (96%)]	학습 손실(Loss) : 0.483350
#
# -------------------------------------------------------------------------------------
# Epoch 3:      Test Loss: 0.0046,     Test Accuracy: 95.58%
# -------------------------------------------------------------------------------------
#
# 학습 Epoch: 4 [0/60000 (0%)]	학습 손실(Loss) : 0.239633
# 학습 Epoch: 4 [6400/60000 (11%)]	학습 손실(Loss) : 0.173099
# 학습 Epoch: 4 [12800/60000 (21%)]	학습 손실(Loss) : 0.148153
# 학습 Epoch: 4 [19200/60000 (32%)]	학습 손실(Loss) : 0.255108
# 학습 Epoch: 4 [25600/60000 (43%)]	학습 손실(Loss) : 0.375861
# 학습 Epoch: 4 [32000/60000 (53%)]	학습 손실(Loss) : 0.125748
# 학습 Epoch: 4 [38400/60000 (64%)]	학습 손실(Loss) : 0.167147
# 학습 Epoch: 4 [44800/60000 (75%)]	학습 손실(Loss) : 0.135093
# 학습 Epoch: 4 [51200/60000 (85%)]	학습 손실(Loss) : 0.255317
# 학습 Epoch: 4 [57600/60000 (96%)]	학습 손실(Loss) : 0.271020
#
# -------------------------------------------------------------------------------------
# Epoch 4:      Test Loss: 0.0041,     Test Accuracy: 96.00%
# -------------------------------------------------------------------------------------
#
# 학습 Epoch: 5 [0/60000 (0%)]	학습 손실(Loss) : 0.353951
# 학습 Epoch: 5 [6400/60000 (11%)]	학습 손실(Loss) : 0.442145
# 학습 Epoch: 5 [12800/60000 (21%)]	학습 손실(Loss) : 0.312104
# 학습 Epoch: 5 [19200/60000 (32%)]	학습 손실(Loss) : 0.579280
# 학습 Epoch: 5 [25600/60000 (43%)]	학습 손실(Loss) : 0.265712
# 학습 Epoch: 5 [32000/60000 (53%)]	학습 손실(Loss) : 0.303649
# 학습 Epoch: 5 [38400/60000 (64%)]	학습 손실(Loss) : 0.345262
# 학습 Epoch: 5 [44800/60000 (75%)]	학습 손실(Loss) : 0.239881
# 학습 Epoch: 5 [51200/60000 (85%)]	학습 손실(Loss) : 0.190300
# 학습 Epoch: 5 [57600/60000 (96%)]	학습 손실(Loss) : 0.255245
#
# -------------------------------------------------------------------------------------
# Epoch 5:      Test Loss: 0.0037,     Test Accuracy: 96.39%
# -------------------------------------------------------------------------------------
#
# 학습 Epoch: 6 [0/60000 (0%)]	학습 손실(Loss) : 0.269850
# 학습 Epoch: 6 [6400/60000 (11%)]	학습 손실(Loss) : 0.502272
# 학습 Epoch: 6 [12800/60000 (21%)]	학습 손실(Loss) : 0.216222
# 학습 Epoch: 6 [19200/60000 (32%)]	학습 손실(Loss) : 0.193962
# 학습 Epoch: 6 [25600/60000 (43%)]	학습 손실(Loss) : 0.050516
# 학습 Epoch: 6 [32000/60000 (53%)]	학습 손실(Loss) : 0.308267
# 학습 Epoch: 6 [38400/60000 (64%)]	학습 손실(Loss) : 0.119464
# 학습 Epoch: 6 [44800/60000 (75%)]	학습 손실(Loss) : 0.355849
# 학습 Epoch: 6 [51200/60000 (85%)]	학습 손실(Loss) : 0.071290
# 학습 Epoch: 6 [57600/60000 (96%)]	학습 손실(Loss) : 0.154438
#
# -------------------------------------------------------------------------------------
# Epoch 6:      Test Loss: 0.0034,     Test Accuracy: 96.80%
# -------------------------------------------------------------------------------------
#
# 학습 Epoch: 7 [0/60000 (0%)]	학습 손실(Loss) : 0.368296
# 학습 Epoch: 7 [6400/60000 (11%)]	학습 손실(Loss) : 0.135668
# 학습 Epoch: 7 [12800/60000 (21%)]	학습 손실(Loss) : 0.056781
# 학습 Epoch: 7 [19200/60000 (32%)]	학습 손실(Loss) : 0.513246
# 학습 Epoch: 7 [25600/60000 (43%)]	학습 손실(Loss) : 0.196092
# 학습 Epoch: 7 [32000/60000 (53%)]	학습 손실(Loss) : 0.481103
# 학습 Epoch: 7 [38400/60000 (64%)]	학습 손실(Loss) : 0.113241
# 학습 Epoch: 7 [44800/60000 (75%)]	학습 손실(Loss) : 0.129083
# 학습 Epoch: 7 [51200/60000 (85%)]	학습 손실(Loss) : 0.117785
# 학습 Epoch: 7 [57600/60000 (96%)]	학습 손실(Loss) : 0.267377
#
# -------------------------------------------------------------------------------------
# Epoch 7:      Test Loss: 0.0032,     Test Accuracy: 96.91%
# -------------------------------------------------------------------------------------
#
# 학습 Epoch: 8 [0/60000 (0%)]	학습 손실(Loss) : 0.222084
# 학습 Epoch: 8 [6400/60000 (11%)]	학습 손실(Loss) : 0.126715
# 학습 Epoch: 8 [12800/60000 (21%)]	학습 손실(Loss) : 0.060860
# 학습 Epoch: 8 [19200/60000 (32%)]	학습 손실(Loss) : 0.322630
# 학습 Epoch: 8 [25600/60000 (43%)]	학습 손실(Loss) : 0.192764
# 학습 Epoch: 8 [32000/60000 (53%)]	학습 손실(Loss) : 0.098691
# 학습 Epoch: 8 [38400/60000 (64%)]	학습 손실(Loss) : 0.143548
# 학습 Epoch: 8 [44800/60000 (75%)]	학습 손실(Loss) : 0.088986
# 학습 Epoch: 8 [51200/60000 (85%)]	학습 손실(Loss) : 0.228082
# 학습 Epoch: 8 [57600/60000 (96%)]	학습 손실(Loss) : 0.038191
#
# -------------------------------------------------------------------------------------
# Epoch 8:      Test Loss: 0.0031,     Test Accuracy: 97.02%
# -------------------------------------------------------------------------------------
#
# 학습 Epoch: 9 [0/60000 (0%)]	학습 손실(Loss) : 0.290062
# 학습 Epoch: 9 [6400/60000 (11%)]	학습 손실(Loss) : 0.104808
# 학습 Epoch: 9 [12800/60000 (21%)]	학습 손실(Loss) : 0.138809
# 학습 Epoch: 9 [19200/60000 (32%)]	학습 손실(Loss) : 0.047853
# 학습 Epoch: 9 [25600/60000 (43%)]	학습 손실(Loss) : 0.360616
# 학습 Epoch: 9 [32000/60000 (53%)]	학습 손실(Loss) : 0.354617
# 학습 Epoch: 9 [38400/60000 (64%)]	학습 손실(Loss) : 0.113347
# 학습 Epoch: 9 [44800/60000 (75%)]	학습 손실(Loss) : 0.069344
# 학습 Epoch: 9 [51200/60000 (85%)]	학습 손실(Loss) : 0.181728
# 학습 Epoch: 9 [57600/60000 (96%)]	학습 손실(Loss) : 0.399826
#
# -------------------------------------------------------------------------------------
# Epoch 9:      Test Loss: 0.0030,     Test Accuracy: 97.08%
# -------------------------------------------------------------------------------------
#
# 학습 Epoch: 10 [0/60000 (0%)]	학습 손실(Loss) : 0.277549
# 학습 Epoch: 10 [6400/60000 (11%)]	학습 손실(Loss) : 0.067153
# 학습 Epoch: 10 [12800/60000 (21%)]	학습 손실(Loss) : 0.090103
# 학습 Epoch: 10 [19200/60000 (32%)]	학습 손실(Loss) : 0.171359
# 학습 Epoch: 10 [25600/60000 (43%)]	학습 손실(Loss) : 0.161946
# 학습 Epoch: 10 [32000/60000 (53%)]	학습 손실(Loss) : 0.161663
# 학습 Epoch: 10 [38400/60000 (64%)]	학습 손실(Loss) : 0.157391
# 학습 Epoch: 10 [44800/60000 (75%)]	학습 손실(Loss) : 0.196320
# 학습 Epoch: 10 [51200/60000 (85%)]	학습 손실(Loss) : 0.056308
# 학습 Epoch: 10 [57600/60000 (96%)]	학습 손실(Loss) : 0.128472
#
# -------------------------------------------------------------------------------------
# Epoch 10:      Test Loss: 0.0028,     Test Accuracy: 97.19%
# -------------------------------------------------------------------------------------
